# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Notebook

# %% [markdown]
# ## Introduction
# This notebook provides an overview of essential tools, languages, and techniques in data science. It includes code examples and explanations to demonstrate key concepts.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Tool           | Use Case                          |
# |----------------|-----------------------------------|
# | Jupyter Notebook | Interactive coding & visualization |
# | Git            | Version control                   |
# | Tableau        | Data visualization                |
# | Apache Spark   | Large-scale data processing       |

# %% [markdown]
# ## Arithmetic Expressions
# Examples:
# - Addition: 3 + 2
# - Multiplication: 4 * 2
# - Division: 3 / 2

# %%
# Multiply and add numbers
result = (5 * 4) + 10
print("Result:", result)  # Output: 30
# Out:
# Result: 30

# %%
# Convert minutes to hours
minutes = 135
hours = minutes // 60
remaining_minutes = minutes % 60
f"{minutes} minutes = {hours} hours and {remaining_minutes} minutes."
# Output: 135 minutes = 2 hours and 15 minutes.
# Out:
# '135 minutes = 2 hours and 15 minutes.'

# %%
# List Objectives
objectives = [
    "Objetive 1: Learn key data science languages and libraries.",
    "Objetive 2: Practice Jupyter Notebook workflows.",
    "Objetive 3: Explore GitHub integration."
]

print("Objectives:")
objectives
# Out:
# Objectives:
# ['Objetive 1: Learn key data science languages and libraries.',
#  'Objetive 2: Practice Jupyter Notebook workflows.',
#  'Objetive 3: Explore GitHub integration.']

# %% [markdown]
# ## Author
# Brihayan Matute
