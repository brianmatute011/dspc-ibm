# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Graded Assessment</font></h1>

# %% [markdown]
# # Introducción
#
# Usando este cuaderno de Python, usted:
#
# 1.  Comprenderá tres conjuntos de datos de Chicago
# 2.  Cargará los tres conjuntos de datos en tres tablas en una base de datos SQLIte
# 3.  Ejecutará consultas SQL para responder a las preguntas de la tarea

# %% [markdown]
# ## Comprender los conjuntos de datos
#
# Para completar los problemas de la tarea en este cuaderno, utilizará tres conjuntos de datos que están disponibles en el Portal de Datos de la ciudad de Chicago:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Indicadores Socioeconómicos en Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Escuelas Públicas de Chicago</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Datos de Crimen en Chicago</a>
#
# ### 1. Indicadores Socioeconómicos en Chicago
#
# Este conjunto de datos contiene una selección de seis indicadores socioeconómicos de importancia para la salud pública y un "índice de dificultad", para cada área comunitaria de Chicago, para los años 2008 - 2012.
#
# Una descripción detallada de este conjunto de datos y el conjunto de datos original se pueden obtener del Portal de Datos de Chicago en:
#
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Escuelas Públicas de Chicago
#
# Este conjunto de datos muestra todos los datos de rendimiento a nivel escolar utilizados para crear las Tarjetas de Informes Escolares de CPS para el año escolar 2011-2012. Este conjunto de datos es proporcionado por el Portal de Datos de la ciudad de Chicago.
#
# Una descripción detallada de este conjunto de datos y el conjunto de datos original se pueden obtener del Portal de Datos de Chicago en:
#
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Datos de Crimen en Chicago
#
# Este conjunto de datos refleja incidentes reportados de crimen (con la excepción de los asesinatos, donde existen datos para cada víctima) que ocurrieron en la ciudad de Chicago desde 2001 hasta la actualidad, menos los últimos siete días.
#
# Una descripción detallada de este conjunto de datos y el conjunto de datos original se pueden obtener del Portal de Datos de Chicago en:
#
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Descargar los conjuntos de datos
#
# Esta tarea requiere que estas tres tablas se llenen con un subconjunto de los conjuntos de datos completos.
#
# En muchos casos, el conjunto de datos a analizar está disponible como un archivo .CSV (valores separados por comas), quizás en internet.
#
# Utilice los enlaces a continuación para leer los archivos de datos utilizando la biblioteca Pandas.
#
# * Datos del Censo de Chicago
#
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01
#
# * Escuelas Públicas de Chicago
#
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01
#
# * Datos de Crimen en Chicago
#
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01
#
# **NOTA:** Asegúrese de usar los conjuntos de datos disponibles en los enlaces anteriores en lugar de obtenerlos directamente del Portal de Datos de Chicago. Las versiones enlazadas aquí son subconjuntos de los conjuntos de datos originales y tienen algunos de los nombres de las columnas modificados para ser más compatibles con bases de datos, lo que facilitará completar esta tarea.

# %% [markdown]
# Execute the below code cell to avoid prettytable default error.

# %%
# !pip install ipython-sql prettytable

import prettytable

prettytable.DEFAULT = 'DEFAULT'

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be loaded into SQLite DB.
# We will create three tables in as under:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**

# %% [markdown]
# Load the `pandas` and `sqlite3` libraries and establish a connection to `FinalDB.db`

# %%
import pandas as pd
import sqlite3

# Establecer conexión con la base de datos SQLite
conn = sqlite3.connect('FinalDB.db')

# Crear un cursor para ejecutar comandos SQL
cursor = conn.cursor()

# Cargar los datos del Censo de Chicago
census_data_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv"
census_df = pd.read_csv('ChicagoCensusData.csv')

# Cargar los datos de las Escuelas Públicas de Chicago
schools_data_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv"
schools_df = pd.read_csv('ChicagoPublicSchools.csv')

# Cargar los datos de Crimen en Chicago
crime_data_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv"
crime_df = pd.read_csv('ChicagoCrimeData.csv')


# Cargar los datos del DataFrame 'census_df' en la tabla 'CENSUS_DATA'
census_df.to_sql('CENSUS_DATA', conn, if_exists='replace', index=False)

# Cargar los datos del DataFrame 'schools_df' en la tabla 'CHICAGO_PUBLIC_SCHOOLS'
schools_df.to_sql('CHICAGO_PUBLIC_SCHOOLS', conn, if_exists='replace', index=False)

# Cargar los datos del DataFrame 'crime_df' en la tabla 'CHICAGO_CRIME_DATA'
crime_df.to_sql('CHICAGO_CRIME_DATA', conn, if_exists='replace', index=False)


# Cerrar la conexión
# conn.close()
# Out:
# 533

# %% [markdown]
# Load the SQL magic module

# %%
# %load_ext sql

# %% [markdown]
# Use `Pandas` to load the data available in the links above to dataframes. Use these dataframes to load data on to the database `FinalDB.db` as required tables.

# %%
census_df.to_sql('CENSUS_DATA', conn, if_exists='replace', index=False)
schools_df.to_sql('CHICAGO_PUBLIC_SCHOOLS', conn, if_exists='replace', index=False)
crime_df.to_sql('CHICAGO_CRIME_DATA', conn, if_exists='replace', index=False)

schools_df.head()
# Out:
#    School_ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School         Street_Address     City State  \
# 0                                 ES        615 W Kemper Pl  Chicago    IL
# 1                                 ES  7511 S South Shore Dr  Chicago    IL
# 2                                 ES     8010 S Kostner Ave  Chicago    IL
# 3                                 ES     4619 S Wolcott Ave  Chicago    IL
# 4                                 HS        3630 S Wells St  Chicago    IL
#
#    ZIP_Code    Phone_Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %% [markdown]
# Establish a connection between SQL magic module and the database `FinalDB.db`

# %%
# %sql sqlite:///FinalDB.db

# %% [markdown]
# You can now proceed to the the following questions. Please note that a graded assignment will follow this lab and there will be a question on each of the problems stated below. It can be from the answer you received or the code you write for this problem. Therefore, please keep a note of both your codes as well as the response you generate.

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(*) AS total_crimes FROM CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community area names and numbers with per capita income less than 11000.

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, COMMUNITY_AREA_NUMBER, PER_CAPITA_INCOME
# FROM CENSUS_DATA
# WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('West Garfield Park', 26.0, 10934),
#  ('South Lawndale', 30.0, 10402),
#  ('Fuller Park', 37.0, 10432),
#  ('Riverdale', 54.0, 8201)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %%sql
# SELECT CASE_NUMBER
# FROM CHICAGO_CRIME_DATA
# WHERE DESCRIPTION LIKE '%MINOR%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %%sql
# SELECT *
# FROM CHICAGO_CRIME_DATA
# WHERE PRIMARY_TYPE = 'KIDNAPPING' AND DESCRIPTION LIKE '%CHILD%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# ### Problem 5
#
# ##### List the kind of crimes that were recorded at schools. (No repetitions)

# %%
# %%sql
# SELECT DISTINCT PRIMARY_TYPE
# FROM CHICAGO_CRIME_DATA
# WHERE LOCATION_DESCRIPTION LIKE '%SCHOOL%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# ### Problem 6
#
# ##### List the type of schools along with the average safety score for each type.

# %%
# %%sql
# SELECT "Elementary, Middle, or High School" AS School_Type,
#        AVG(SAFETY_SCORE) AS AVERAGE_SAFETY_SCORE
# FROM CHICAGO_PUBLIC_SCHOOLS
# GROUP BY "Elementary, Middle, or High School";
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY
# FROM CENSUS_DATA
# ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC
# LIMIT 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone? Display the coumminty area number only.

# %%
# %%sql
# SELECT COMMUNITY_AREA_NUMBER
# FROM CHICAGO_CRIME_DATA
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY COUNT(*) DESC
# LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0,)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that has most number of incidents
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME
# FROM CENSUS_DATA
# WHERE HARDSHIP_INDEX = (
#     SELECT MAX(HARDSHIP_INDEX)
#     FROM CENSUS_DATA
# );
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',)]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %%sql
# SELECT COMMUNITY_AREA_NAME
# FROM CENSUS_DATA
# WHERE COMMUNITY_AREA_NUMBER = (
#     SELECT COMMUNITY_AREA_NUMBER
#     FROM CHICAGO_CRIME_DATA
#     GROUP BY COMMUNITY_AREA_NUMBER
#     ORDER BY COUNT(*) DESC
#     LIMIT 1
# );
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin',)]

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
# <h4>Abhishek Gagneja</h4>
# <!--
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# |2023-10-18  | 2.6     | Abhishek Gagneja  | Modified instruction set |
# | 2022-03-04 | 2.5     | Lakshmi Holla     | Changed markdown.                   |
# | 2021-05-19 | 2.4     | Lakshmi Holla     | Updated the question                           |
# | 2021-04-30 | 2.3     | Malika Singla     | Updated the libraries                          |
# | 2021-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
# -->
# ## <h3 align="center"> © IBM Corporation 2023. All rights reserved. <h3/>
